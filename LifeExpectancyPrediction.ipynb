# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import seaborn as sns
import matplotlib.pyplot as pyplot
import pickle
from matplotlib import style

data = pd.read_csv("Life Expectancy Data.csv")
data.columns = data.columns.str.replace(' ','_')
# data.groupby('Country').mean()

# for col in data.columns:
#     print(col)

# Status = {'Developing': 0,'Developed': 1}

# data.Status = [Status[item] for item in data.Status]

sns.heatmap(data.corr())

# %%
data = data.dropna()

X = data[['under-five_deaths_','infant_deaths','Alcohol','Adult_Mortality','Schooling','_BMI_','GDP','Population'
         ,'Income_composition_of_resources','_HIV/AIDS', 'Measles_',
          '_thinness_5-9_years', 'percentage_expenditure','Year']]


y = data['Life_expectancy_']

# best = 0;

# for _ in range(100):
#     X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

#     model = linear_model.LinearRegression()

#     model.fit(X_train, y_train)

#     prediction = model.score(X_test, y_test)
#     print(prediction)

#     if prediction > best:
#         best = prediction
#         with open("stmodel.pickle", "wb") as f:
#             pickle.dump(model, f)

# print("")
# print(best)

pickle_in = open("stmodel.pickle", "rb")
model = pickle.load(pickle_in)

# this model has an accuracy of 90.8%
